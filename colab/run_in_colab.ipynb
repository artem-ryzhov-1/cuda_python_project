# %% [markdown]
# <a href="https://colab.research.google.com/github/account548567/cuda_python_project/blob/main/colab/run_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# WARNING: This deletes everything in the current directory!
# Run only if you're okay wiping everything cloned so far.

# %cd /content
# !rm -rf cuda_python_project
# Out:
# /content

# %%
# Clone GitHub repo
# %cd /content
# !if [ ! -d "cuda_python_project" ]; then git clone https://account548567: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@github.com/account548567/cuda_python_project.git; fi
# %cd cuda_python_project
# Out:
# /content
# Cloning into 'cuda_python_project'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 64 (delta 16), reused 44 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 512.64 KiB | 14.24 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/cuda_python_project

# %%
# Update with the latest changes from GitHub
# %cd /content/cuda_python_project
# !git pull origin main
# Out:
# /content/cuda_python_project
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.01 KiB | 1.01 MiB/s, done.
# From https://github.com/account548567/cuda_python_project
#  * branch            main       -> FETCH_HEAD
#    0b96204..7dda4a7  main       -> origin/main
# Updating 0b96204..7dda4a7
# Fast-forward
#  scripts/setup_colab.sh | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd /content/cuda_python_project
# !bash scripts/setup_colab.sh
# Out:
# /content/cuda_python_project
# scripts/setup_colab.sh: line 1: fg: no job control
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !apt-get install -y tree
# !tree /content/cuda_python_project
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 46 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (87.4 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/cuda_python_project
# ├── cuda
# │   ├── lindblad_gpu
# │   ├── Makefile
# │   └── src
# │       ├── commutator
# │       │   └── commutator.cuh
# │       ├── constants.cuh
# │       ├── dissipators
# ...

# %%
# %cd /content/cuda_python_project

# Run the binary with arguments
# !./lindblad_gpu grid last ram unrolled MySimSharedMemory -0.006 0.006 0.0 0.01 774 645 10000 10 1 70819 21 0.0002 0.0033 0.25 0.25 0.25 0.25 output_rho_avg.csv output_rho_dynamics_single_mode.csv 0.00011608757555650906 0 0 0.8 3.6 50.0 225.0 12.0 54.0 50.0 12.0 0 0 0 0.8 0.0015731484686413405 3.6 False output_rho_dynamics_single_mode_log.csv output_rho_dynamics_single_mode_log.h5 one_thread_per_traj
# Out:
# /content/cuda_python_project
#
# --- Listing received arguments ---
# 1.  single_mode_flag: grid
# 2.  avg_periods_ouput_option: last
# 3.  ouput_option: ram
# 4.  unrolled_option: unrolled
# 5.  ram_shared_mmap_name: MySimSharedMemory
# 6.  eps0_min: -0.006
# 7.  eps0_max: 0.006
# 8.  A_min: 0.0
# 9.  A_max: 0.01
# 10. N_points_eps0_range: 774
# 11. N_points_A_range: 645
# 12. N_steps_period: 10000
# 13. N_periods: 10
# 14. N_periods_avg: 1
# 15. alpha: 70819
# 16. nu: 21
# 17. eps0_target_singlepoint: 0.0002
# 18. A_target_singlepoint: 0.0033
# 19. rho00_init: 0.25
# 20. rho11_init: 0.25
# 21. rho22_init: 0.25
# 22. rho33_init: 0.25
# 23. path_output_csv: output_rho_avg.csv
# 24. path_dynamics_single_mode_output_csv: output_rho_dynamics_single_mode.csv
# 25. delta_C: 0.00011608757555650906
# 26. delta_L: 0
# 27. delta_R: 0
# 28. g_en: 0.8
# 29. g_phi: 3.6
# 30. gL_en: 50.0
# 31. gL_phi: 225.0
# 32. gR_en: 12.0
# 33. gR_phi: 54.0
# 34. Gamma_L0: 50.0
# 35. Gamma_R0: 12.0
# ...
